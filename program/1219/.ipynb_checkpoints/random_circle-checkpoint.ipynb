# %%
# ランダム行列の固有値をプロットし、ランダム行列の円則を確認する
import numpy as np
import math
import matplotlib.pyplot as plt
arr = np.random.normal(0,math.sqrt(1.0/1000), (1000, 1000))
m = np.asmatrix(arr)
t = np.linalg.eigvals(m)
# %matplotlib inline
for i in range(len(t)):
    plt.scatter(t.real, t.imag)
