# %%
from mylib.nestlist import *
import random
import matplotlib.pyplot as plt

l = nestlist1(lambda x: x + (-1)**random.randint(0, 1), 0, 1000)

plt.plot(l)
plt.show()

# %%
a = 0.9
b = -0.6013
c = 2.0
d = 0.50
l = nestlist2(lambda x,y: x**2 - y**2 + a*x + b*y, lambda x,y:2*x*y + c*x + d*y, -0.72, -0.64, 10)
print(l)
plt.plot()
plt.show()
# Out:
# [[-0.72, -0.64], [-0.15436800000000017, -0.8384], [-0.31388636057600017, -0.46909173760000006], [-0.12195527362846065, -0.5678355933689282], [-0.07588437630372818, -0.3893272536108115], [0.019989267085694262, -0.28734466777626244], [0.108603301810164, -0.11518141833640229], [0.16552947650891056, 0.13459772977510476], [0.07732637267695087, 0.4429176014032953], [-0.3869292520360193, 0.44460996907813416], [-0.6635440797616055, -0.8956187250992919]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-f41f6516b946> in <module>()
#       5 l = nestlist2(lambda x,y: x**2 - y**2 + a*x + b*y, lambda x,y:2*x*y + c*x + d*y, -0.72, -0.64, 10)
#       6 print(l)
# ----> 7 plt.plot(l[:,0],l[:,1])
#       8 plt.show()
#
# TypeError: list indices must be integers or slices, not tuple
