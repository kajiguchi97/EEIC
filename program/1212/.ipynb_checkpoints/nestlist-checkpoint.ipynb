# %%
from mylib.nestlist import *
import random
import matplotlib.pyplot as plt

# %%
l = nestlist1(lambda x: x + (-1)**random.randint(0, 1), 0, 1000)

plt.plot(l)
plt.show()

# %%
a = 0.9
b = -0.6013
c = 2.0
d = 0.50
l = nestlist2(lambda x,y: x**2 - y**2 + a*x + b*y, lambda x,y:2*x*y + c*x + d*y, -0.72, -0.64, 10000)

plt.plot(l[0], l[1])
plt.show()
